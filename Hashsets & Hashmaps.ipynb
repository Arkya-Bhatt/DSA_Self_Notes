# %% [markdown]
# # HASHSETS

# %%
s = set()
print(s)
# Out:
# set()

# %%
# Add item into Set - O(1)
s.add(1)
s.add(2)
s.add(3)

print(s)
# Out:
# {1, 2, 3}

# %%
# Lookup if item in set - O(1)
if 1 not in s:
    print(True)
else:
    print(False)
# Out:
# False

# %%
# Remove item from set - O(1)
s.remove(3)

print(s)
# Out:
# {1, 2}

# %%
# Set construction - O(S) - S is the length of the string
string = 'aaaaaaabbbbbbbbbbbccccccccceeeeeeeee'
sett = set(string)

sett
# Out:
# {'a', 'b', 'c', 'e'}

# %%
# Loop over items in set - O(n)
for x in s:
    print(x)
# Out:
# 1
# 2

# %% [markdown]
# # HASHMAPS - DICTIONARIES

# %%
d = {'greg': 1, 'steve': 2, 'rob': 3}

print(d)
# Out:
# {'greg': 1, 'steve': 2, 'rob': 3}

# %%
# Add key:val in dictionary: O(1)
d['arsh'] = 4

print(d)
# Out:
# {'greg': 1, 'steve': 2, 'rob': 3, 'arsh': 4}

# %%
# Check for presence of key in dictionary: O(1)
if 'greg' in d:
    print(True)
# Out:
# True

# %%
# Check the value corresponding to a key in the dictionary: O(1)
print(d['greg'])
# Out:
# 1

# %%
# Loop over the key:val pairs of the dictionary: O(n)
for key, val in d.items():
    print(f'key {key}: val {val}')
# Out:
# key greg: val 1
# key steve: val 2
# key rob: val 3
# key arsh: val 4

# %% [markdown]
# # DEAFULTDICT

# %%
from collections import defaultdict

default_num = defaultdict(int)
default_lst = defaultdict(list)

default_num[1]
# Out:
# 0

# %%
default_lst[2]
# Out:
# []

# %%
default_num
# Out:
# defaultdict(int, {1: 0})

# %%
default_lst
# Out:
# defaultdict(list, {2: []})

# %% [markdown]
# # COUNTER

# %%
from collections import Counter

s = "aaaaaaabbbbbbbbcccccdddddd"

counter = Counter(s)

print(counter)
# Out:
# Counter({'b': 8, 'a': 7, 'd': 6, 'c': 5})
